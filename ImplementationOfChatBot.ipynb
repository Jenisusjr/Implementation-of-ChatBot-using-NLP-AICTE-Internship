# %%
pip install streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install nltk scikit-learn streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import ssl
import streamlit as st
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %%
import nltk
import random
import os
import ssl
import streamlit as st
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %%
ssl._create_default_https_context = ssl._create_unverified_context
nltk.data.path.append(os.path.abspath('nltk_data'))
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
intents = [
    {
        'tag': 'greeting',
        'patterns': [
            'Hey there!', 'Yo!', 'Hello, friend!', 'Howdy!', 'Hey buddy!',
            'What’s new?', 'Greetings!', 'Hiya!', 'Good day!', 'Long time no see!'
        ],
        'responses': [
            'Hey! Nice to see you!', 'Yo! How’s it going?', 'Howdy, partner!', 
            'Hello there! What’s up?', 'Hey buddy! How’s life treating you?',
            'Hiya! What can I do for you today?', 'Good day! Need something?',
            'Long time no see! What’s new?'
        ]
    },
    {
        'tag': 'goodbye',
        'patterns': [
            'Catch you later!', 'I’m off!', 'See ya!', 'Gotta go!', 'Take it easy!',
            'Farewell!', 'Adios!', 'Later, alligator!', 'Until next time!', 'Peace out!'
        ],
        'responses': [
            'Catch you later, alligator!', 'See ya! Have a great day!',
            'Take care and stay awesome!', 'Adios, amigo!', 'Farewell! Hope to see you soon!',
            'Until next time, take care!', 'Gotta go? No worries! See you later!',
            'Peace out! Stay cool!'
        ]
    },
    {
        "tag": "thanks",
        "patterns": [
            "I appreciate it so much!", "Much obliged!", "Big thanks!", "Thanks a ton!",
            "A million thanks!", "Endless gratitude!", "Cheers for that!", "Deeply grateful!"
        ],
        "responses": [
            "You're very welcome!", "No worries, glad I could help!", "Anytime, friend!", 
            "Happy to assist!", "No problem at all!", "Always here to help!", 
            "Your gratitude is appreciated!", "Glad I could be of service!"
        ]
    },
    {
        "tag": "about",
        "patterns": [
            "Tell me something cool about you!", "Are you human?", "Do you have a name?", 
            "What’s your backstory?", "What’s your deal?", "Are you self-aware?",
            "Do you have feelings?", "Can you think like a human?"
        ],
        "responses": [
            "I’m a digital being with an endless supply of knowledge—cool, right?",
            "Nope, I’m not human, but I can chat like one!",
            "You can call me your AI buddy!", "Backstory? I was born in the cloud!",
            "My deal? Helping awesome people like you!", "I don’t have feelings, but I understand emotions!",
            "I may not think like a human, but I can definitely help like one!"
        ]
    },
    {
        "tag": "help",
        "patterns": [
            "Throw me a lifeline!", "I’m stuck!", "SOS! Need assistance!", 
            "Can you guide me?", "I need a helping hand!", "Help me out, will you?", 
            "I’m lost, can you assist?", "Is there a way you can help?"
        ],
        "responses": [
            "Of course! What’s on your mind?", "I got you! What do you need help with?",
            "Absolutely! Just tell me the issue.", "I’m here to help! Lay it on me.",
            "Let’s tackle this together! What’s the problem?", "You’re not alone—I’m here to assist!"
        ]
    },
    {
        "tag": "age",
        "patterns": [
            "Were you around in the 90s?", "How many years old are you?",
            "When were you created?", "Do AI age like humans?", "Are you older than me?",
            "Do you celebrate birthdays?", "Are you young or old?"
        ],
        "responses": [
            "I was born in the digital realm, so I don’t really age!",
            "I don’t have birthdays, but I can help you remember yours!",
            "I’m timeless, like the stars!", "Unlike humans, I don’t grow old, just smarter!",
            "I might be younger than you in human years, but I have infinite knowledge!",
            "No wrinkles or gray hairs for me—I stay forever fresh!"
        ]
    },
    {
        "tag": "fitness",
        "patterns": [
            "How can I stay fit?", "Give me some fitness tips!", "Best ways to stay healthy?",
            "How do I maintain an active lifestyle?", "What’s the secret to staying in shape?"
        ],
        "responses": [
            "To stay fit, eat healthy, exercise regularly, and drink plenty of water!",
            "A balanced diet and regular workouts will keep you in top shape!",
            "Stay active by walking, stretching, or playing sports every day.",
            "Fitness isn’t just about workouts—sleep well and manage stress too!"
        ]
    },
    {
        "tag": "study",
        "patterns": [
            "How do I study effectively?", "Tips to improve focus while studying?", 
            "How do I remember things better?", "Best study techniques?", "How can I score top marks?"
        ],
        "responses": [
            "To study effectively, break topics into small sections, use flashcards, and take regular breaks!",
            "Try active recall and spaced repetition—it works wonders for memory!",
            "Make summaries, use mind maps, and teach others to reinforce what you learn.",
            "To score well, attempt all questions, structure answers well, and highlight key points!"
        ]
    },
    {
        "tag": "time_management",
        "patterns": [
            "How do I manage my time better?", "Best ways to stop procrastinating?", 
            "Time management hacks?", "How do I plan my day?", "How do I become more productive?"
        ],
        "responses": [
            "Prioritize tasks, set deadlines, and break big tasks into smaller steps!",
            "Use the Pomodoro technique: work in short bursts with breaks in between!",
            "Make a to-do list every morning and stick to it.",
            "Eliminate distractions, set clear goals, and schedule your tasks wisely!"
        ]
    }
]
